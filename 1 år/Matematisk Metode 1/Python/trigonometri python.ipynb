# %%
import numpy as np
import matplotlib.pyplot as plt

def f(x1):
    return np.sin(x)

def g(x2):
    return np.arcsin(x2)

def h(x1):
    return x1

x1 = np.linspace(- np.pi/2, np.pi/2, 1001)
x2 = np.linspace(- 1, 1, 101)


plt.figure()
plt.plot(x1, f(x1))
plt.plot(x2,g(x2))
plt.plot(x1,h(x1))
plt.grid()
plt.xlim(- np.pi/2, np.pi/2)
plt.ylim(- np.pi/2, np.pi/2)
plt.legend(['y=sin(x)', 'y=sin^-1(x)','y=x'])
