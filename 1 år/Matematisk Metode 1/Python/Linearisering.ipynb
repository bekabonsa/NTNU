# %%
import numpy as np
import math
import matplotlib.pyplot as plt

#lineariserer rundt punktet a
a = math.sqrt(2)

def F(x):
    return 3*np.e**(1-x**2/2)

def f(x):
    return -3*x*np.e**(1-x**2/2)

def L(x):
    return F(a)+f(a)*(x-a)

range = np.arange(-1,5,0.001)
#plotting Original func
plt.plot(range,F(range))
#plotting tangent line
plt.plot(range,l(range))
plt.grid()

#Comparison
print(F(1.5))
print(L(1.5))
# Out:
# 2.6474907077537866
# 2.636038969321072
